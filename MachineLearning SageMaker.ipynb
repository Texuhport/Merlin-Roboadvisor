# %% [markdown]
# # Import Libraries

# %%
# Import the Pandas library and alias it as "pd" for data calculations
import pandas as pd

import numpy as np

# Import the pathlib function from the Path package for working with file paths
from pathlib import Path

# Import the csv package for reading and writing CSV files
import csv

# Import the 'datetime' class from the 'datetime' module for working with dates and times
from datetime import datetime

# Ignore warnings to prevent them from being displayed
import warnings
warnings.filterwarnings('ignore')

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, mean_absolute_error, mean_squared_error, r2_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsRegressor

import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.preprocessing import MinMaxScaler

import boto3
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.0' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## AWS Configurations

# %%
access_key = 'AKIAQV5XYIS3UU4VTD4J'
secret_key = '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'

# %%
#DynamoDV Config
dynamodb = boto3.resource('dynamodb', region_name='us-east-1', aws_access_key_id= access_key, aws_secret_access_key= secret_key)


table = dynamodb.Table('lex_result')

response = table.scan()
first_item = response['Items'][0]
df = pd.DataFrame([first_item]).set_index(['email_address'])

# %%
df
# Out:
#                    DebtService Education Charitable CreditCard  \
# email_address
# arthur@camelot.com         350       300       3000       3000
#
#                    Non-essentialFood HouseholdNumber CreditScore  \
# email_address
# arthur@camelot.com               300               4         700
#
#                                Contact           Occupation Wellness  ...  \
# email_address                                                         ...
# arthur@camelot.com  arthur@camelot.com  Software Programmer      300  ...
#
#                    VacationTravel    State Housing PersonalLoan Clothing  \
# email_address
# arthur@camelot.com            300  Ontario    6000        50000      300
#
#                    Location Medical Income   Assets Age
# email_address
# arthur@camelot.com  Toronto     300  75000  1000000  22
#
# [1 rows x 26 columns]

# %%
#S3 Config
bucket_name = 'michaelbackend'
prefix = 'Resources/'
s3client = boto3.client('s3')
allfiles = s3client.list_objects(Bucket=bucket_name, Prefix=prefix)
y = "ui" 
csvlist=[]
for x in allfiles.get('Contents', []):
    file_key = x['Key']
    y = y + y
    
    if file_key.endswith('.csv'):
        obj_data = s3client.get_object(Bucket=bucket_name, Key=file_key)
        y = pd.read_csv(obj_data['Body'])

# %% [markdown]
# ## Input Reading

# %%
#Read The 'user input' csvs
ui1 = pd.read_csv('s3://michaelbackend/Resources/UserInput/Income Sources By Age and Tax.csv')
ui2 = pd.read_csv('s3://michaelbackend/Resources/UserInput/Household Liabilities.csv')
ui4 = pd.read_csv('s3://michaelbackend/Resources/UserInput/Canada_per_capita_income.csv')
ui5 = pd.read_csv('s3://michaelbackend/Resources/UserInput/canada_cpi.csv')
ui6 = pd.read_csv('s3://michaelbackend/Resources/UserInput/ca_real_estate.csv')
ui7 = pd.read_csv('s3://michaelbackend/Resources/UserInput/Average  OSAP Debt.csv')
ui8a = pd.read_csv('s3://michaelbackend/Resources/UserInput/World Happiness Reports/2015.csv')
ui8b = pd.read_csv('s3://michaelbackend/Resources/UserInput/World Happiness Reports/2016.csv')
ui8c = pd.read_csv('s3://michaelbackend/Resources/UserInput/World Happiness Reports/2017.csv')
ui8d = pd.read_csv('s3://michaelbackend/Resources/UserInput/World Happiness Reports/2018.csv')
ui8e = pd.read_csv('s3://michaelbackend/Resources/UserInput/World Happiness Reports/2019.csv')
ui8f = pd.read_csv('s3://michaelbackend/Resources/UserInput/World Happiness Reports/2020.csv')
ui8g = pd.read_csv('s3://michaelbackend/Resources/UserInput/World Happiness Reports/2021.csv')
ui8h = pd.read_csv('s3://michaelbackend/Resources/UserInput/World Happiness Reports/2022.csv')
ui9a = pd.read_csv('s3://michaelbackend/Resources/UserInput/Household Wealth/All Household Wealth Stats.csv')
ui9b = pd.read_csv('s3://michaelbackend/Resources/UserInput/Household Wealth/Highest Income Wealth Stats.csv')
ui9c = pd.read_csv('s3://michaelbackend/Resources/UserInput/Household Wealth/Household Wealth Above 65.csv')
ui9d = pd.read_csv('s3://michaelbackend/Resources/UserInput/Household Wealth/Household Wealth Below 64.csv')
ui9e = pd.read_csv('s3://michaelbackend/Resources/UserInput/Household Wealth/Low Income Household Wealth Stats.csv')
ui9f = pd.read_csv('s3://michaelbackend/Resources/UserInput/Household Wealth/Median Income Wealth.csv')
ui9g = pd.read_csv('s3://michaelbackend/Resources/UserInput/Household Wealth/Under 35s Household Wealth.csv')
ui9h = pd.read_csv('s3://michaelbackend/Resources/UserInput/Household Wealth/Under 44 Household Wealth.csv')
ui9i = pd.read_csv('s3://michaelbackend/Resources/UserInput/Household Wealth/Under 54 Household Wealth.csv')
ui10a = pd.read_csv('s3://michaelbackend/Resources/UserInput/Census/2001 Census.csv')
ui10b = pd.read_csv('s3://michaelbackend/Resources/UserInput/Census/2006 Census.csv')
ui10c = pd.read_csv('s3://michaelbackend/Resources/UserInput/Census/2011 Census.csv')
ui10d = pd.read_csv('s3://michaelbackend/Resources/UserInput/Census/2016 Census.csv')
ui10e = pd.read_csv('s3://michaelbackend/Resources/UserInput/Census/2021 Census.csv')
ui11 = pd.read_csv('s3://michaelbackend/Resources/UserInput/Age Classification Map.csv')
ui12 = pd.DataFrame

# %%
#Read in the 'Canada' csvs
CA1 = pd.read_csv('s3://michaelbackend/Resources/Canada/Vital Food Costs.csv')
#CA2a = pd.read_csv(Path(r"C:\Users\Oluwa\GITHUB\Bootcamp\ASSIGNMENTS\Group-3-Project\Resources\Canada\USDCAD Monthly Price.csv"))
#CA2b = pd.read_csv(Path(r"C:\Users\Oluwa\GITHUB\Bootcamp\ASSIGNMENTS\Group-3-Project\Resources\Canada\USDCAD Daily Price.csv"))
#CA3 = pd.read_csv(Path(r"C:\Users\Oluwa\GITHUB\Bootcamp\ASSIGNMENTS\Group-3-Project\Resources\Canada\travel insurance.csv"))
CA4 = pd.read_csv('s3://michaelbackend/Resources/Canada/Share Of New Mortgage Holders With 660 Credit Score Or Below.csv')
#CA5 = pd.read_csv(Path(r"C:\Users\Oluwa\GITHUB\Bootcamp\ASSIGNMENTS\Group-3-Project\Resources\Canada\Monthly retail trade sales by province and territory.csv"))
#CA6 = pd.read_csv(Path(r"C:\Users\Oluwa\GITHUB\Bootcamp\ASSIGNMENTS\Group-3-Project\Resources\Canada\Interest Rates.csv"))
CA7 = pd.read_csv('s3://michaelbackend/Resources/Canada/Housing Market Indicators Report.csv')
#CA8 = pd.read_csv(Path(r"C:\Users\Oluwa\GITHUB\Bootcamp\ASSIGNMENTS\Group-3-Project\Resources\Canada\Government of Canada Spend By Industry.csv"))
#CA9 = pd.read_csv(Path(r"C:\Users\Oluwa\GITHUB\Bootcamp\ASSIGNMENTS\Group-3-Project\Resources\Canada\Farm Income Stats.csv"))
CA10 = pd.read_csv('s3://michaelbackend/Resources/Canada/Distributions of household economic accounts, income, consumption and saving.csv')
#CA11 = pd.read_csv(Path(r"C:\Users\Oluwa\GITHUB\Bootcamp\ASSIGNMENTS\Group-3-Project\Resources\Canada\Canada_per_capita_income.csv"))
#CA12 = pd.read_csv(Path(r"C:\Users\Oluwa\GITHUB\Bootcamp\ASSIGNMENTS\Group-3-Project\Resources\Canada\canada_gas_prices.csv"))
#CA13 = pd.read_csv(Path(r"C:\Users\Oluwa\GITHUB\Bootcamp\ASSIGNMENTS\Group-3-Project\Resources\Canada\canada_cpi.csv"))
#CA14 = pd.read_csv(Path(r"C:\Users\Oluwa\GITHUB\Bootcamp\ASSIGNMENTS\Group-3-Project\Resources\Canada\Canada Historical GDP.csv"))
#CA15 = pd.read_csv(Path(r"C:\Users\Oluwa\GITHUB\Bootcamp\ASSIGNMENTS\Group-3-Project\Resources\Canada\Canada DeathData.csv"))
#CA17 = pd.read_csv(Path(r"C:\Users\Oluwa\GITHUB\Bootcamp\ASSIGNMENTS\Group-3-Project\Resources\Canada\Average Scheduled Monthly Payments On Mortgages.csv"))
#CA18 = pd.read_csv(Path(r"C:\Users\Oluwa\GITHUB\Bootcamp\ASSIGNMENTS\Group-3-Project\Resources\Canada\Annual_Payday_Loan_Data.csv"))
#CA19a = pd.read_csv(Path(r"C:\Users\Oluwa\GITHUB\Bootcamp\ASSIGNMENTS\Group-3-Project\Resources\Canada\Wages\Average Weekly Wage.csv"))
#CA19b = pd.read_csv(Path(r"C:\Users\Oluwa\GITHUB\Bootcamp\ASSIGNMENTS\Group-3-Project\Resources\Canada\Wages\Hourly Wage Average By Industry.csv"))
#CA19c = pd.read_csv(Path(r"C:\Users\Oluwa\GITHUB\Bootcamp\ASSIGNMENTS\Group-3-Project\Resources\Canada\Wages\Average Weekly Wage.csv"))
#CA19d = pd.read_csv(Path(r"C:\Users\Oluwa\GITHUB\Bootcamp\ASSIGNMENTS\Group-3-Project\Resources\Canada\Wages\Household Wealth Below 64.csv"))
#CA20a = pd.read_csv(Path(r"C:\Users\Oluwa\GITHUB\Bootcamp\ASSIGNMENTS\Group-3-Project\Resources\Canada\Income Groups\Canada Employment Income.csv"))
#CA20b = pd.read_csv(Path(r"C:\Users\Oluwa\GITHUB\Bootcamp\ASSIGNMENTS\Group-3-Project\Resources\Canada\Income Groups\Canada Investment Income.csv"))
#CA20c = pd.read_csv(Path(r"C:\Users\Oluwa\GITHUB\Bootcamp\ASSIGNMENTS\Group-3-Project\Resources\Canada\Income Groups\Canada Self Employment Income.csv"))
#CA20d = pd.read_csv(Path(r"C:\Users\Oluwa\GITHUB\Bootcamp\ASSIGNMENTS\Group-3-Project\Resources\Canada\Income Groups\Canada Social Assistance Income.csv"))
#CA20e = pd.read_csv(Path(r"C:\Users\Oluwa\GITHUB\Bootcamp\ASSIGNMENTS\Group-3-Project\Resources\Canada\Income Groups\Canada Total Income.csv"))
#CA21a = pd.read_csv(Path(r"C:\Users\Oluwa\GITHUB\Bootcamp\ASSIGNMENTS\Group-3-Project\Resources\Canada\Import Export\Canadian Export Industries (millions of CAD).csv"))
#CA21b = pd.read_csv(Path(r"C:\Users\Oluwa\GITHUB\Bootcamp\ASSIGNMENTS\Group-3-Project\Resources\Canada\Import Export\Canadian Import Industries (millions of CAD).csv"))
#CA21c = pd.read_csv(Path(r"C:\Users\Oluwa\GITHUB\Bootcamp\ASSIGNMENTS\Group-3-Project\Resources\Canada\Import Export\Total Exports (millions of CAD).csv"))
#CA21d = pd.read_csv(Path(r"C:\Users\Oluwa\GITHUB\Bootcamp\ASSIGNMENTS\Group-3-Project\Resources\Canada\Import Export\Total Imports (millions of CAD).csv"))

# %% [markdown]
# ## Clean User Input Data

# %%
#Clean the first CSV
ui1 = ui1.set_index('REF_DATE')
ui1 = ui1[~ui1['Gender (3a)'].isin(['Women+', 'Men+'])]
ui1 = ui1.drop(columns=['Gender (3a)','Income statistics (16):Total - Population aged 15 years and over with an amount - 25% sample data (2015)[12]', 'Income statistics (16):Percentage with an amount (%) - 25% sample data (2015)[13]', 'Income statistics (16):Total - Population aged 15 years and over with an amount - 100% data (2015)[9]', 'Income statistics (16):Percentage with an amount (%) - 100% data (2015)[10]','Income statistics (16):Percentage with an amount (%) - 25% sample data (2020)[5]','Income statistics (16):Total - Population aged 15 years and over with an amount - 25% sample data (2020)[4]','Income statistics (16):Percentage with an amount (%) - 100% data (2020)[2]','Income statistics (16):Total - Population aged 15 years and over with an amount - 100% data (2020)[1]','DGUID','Coordinate', 'Symbol', 'Symbol.1', 'Symbol.2', 'Symbol.3', 'Symbol.4', 'Symbol.5', 'Symbol.6', 'Symbol.7', 'Symbol.8', 'Symbol.9', 'Symbol.10', 'Symbol.11', 'Symbol.12', 'Symbol.13', 'Symbol.14', 'Symbol.15'])
ui1 = ui1.rename(columns={
    'GEO': 'Location',
    'Age (9)': 'Age Group',
    'Income sources and taxes (32)': 'Income Source Types',
    'Income statistics (16):Median amount ($) (2020)[3]': '1 Year Median',
    'Income statistics (16):Average amount ($) (2020)[6]': '1 Year Average',
    'Income statistics (16):Aggregate amount ($\'000) (2020)[7]': '1 Year Aggregate',
    'Income statistics (16):As a share of total income (%) (2020)[8]': 'Percent of Total Income (1 Year)',
    'Income statistics (16):Median amount ($) (2015)[11]': '5 Year Median',
    'Income statistics (16):Average amount ($) (2015)[14]': '5 Year Average',
    'Income statistics (16):Aggregate amount ($\'000) (2015)[15]': '5 Year Aggregate',
    'Income statistics (16):As a share of total income (%) (2015)[16]': 'Percent of Total Income (5 Year)'
})
ui1['Location'] = ui1['Location'].str.split('(').str[0]
income_2021_bylocation_byage_byincomesource = ui1.groupby(['Location', 'Age Group', 'Income Source Types']).mean()


#Clean The Second
ui2.columns = ui2.iloc[0]
ui2 = ui2.iloc[1:]
ui2 = ui2.loc[:, ~ui2.iloc[0].str.contains('Symbol')]
ui2 = ui2.dropna()
ui2 = ui2.transpose()
ui2 = ui2.reset_index()
ui2.columns = ui2.iloc[0]
ui2 = ui2.iloc[1:]
ui2 = ui2.set_index('Period')
ui2 = ui2.drop(columns= ['Geography','Of which: off balance-sheet NHA-MBS 9 10 12', 'Non-residential mortgages 14','Of which: real estate secured lending 14','Residential mortgages 14', 'Chartered banks 10 14','Non-banks 10 14','Chartered banks 13 14','Non-banks 13 14','Home equity lines of credit 14','Chartered banks 14','Non-banks 14 15'])
household_liability_indexed_by_date = ui2.rename(columns={
    'Non-mortgage loans': 'Total Non-Mortgage',
    'Chartered banks 1': 'Non-Mortgage Chartered Banks',
    'Personal loans 1 2': 'Non-Mortgage Personal Loans',
    'Of which: Auto loans 1 2': 'Personal Loans for Automobiles',
    'Credit cards 1 2': 'Credit Card Liabilities',
    'Lines of credit 1 2 4' : 'Non-Mortgage Lines of credit',
    'Lines of credit, of which: excluding home equity lines of credit 1 2': 'Non-Mortgage Lines Of Credit (Excluding Home Equity LsOc)',
    'Other personal loans 1 2': 'Other personal loans',
    'Unincorporated business 1 2': 'Unincorporated Business',
    'Non-banks 1' : 'Non-bank Non-Mortgage loans',
    'Government 1 5' : 'Government Non-Mortgage Loans',
    'Non-bank financial corporations 1 5' : 'Non-bank Financial Institutions Non-Mortgage Loans',
    'Credit unions and caisse populaires 1 5' : 'Non-Mortgage Loans From Credit unions and caisse populaires',
    'Trust companies and mortgage loan companies 1 5' : 'Non-Mortgage Loans From Trust and Mortgage Loan Companies',
    'Financial vehicle corporations engaged in securitization 1 6' : 'Non-Mortgage Securities From Securitization Corporations',
    'Other financial corporations n.e.i. 1 7' : 'Other Non-Mortgage financial corporations',
    'Other lenders n.e.i. 1 8' : 'Other Non-Mortgage Lenders',
    'Mortgage Loans' : 'Total Mortgage',
    'Residential mortgages 9' : 'Residential Mortgages Total',
    'Chartered banks 9 10' : 'Residential Mortgages From Chartered Banks',
    'Non-banks 9 10' : 'Residential Mortgages From Non-Banks',
    'Government 9 10' : 'Residential Mortgages from Government Loans',
    'Non-bank financial corporations 9 10 11' : 'Residential Mortgages from Non-Bank Financial Institutions',
    'Credit unions and caisse populaires 9 10' : 'Residential Mortgages from Credit unions and caisse populaires',
    'Trust companies and mortgage loan companies 9 10' : 'Residential Mortgages From Trust and Mortgage Loan Companies',
    'Financial vehicle corporations engaged in securitization 6 9 10' : 'Residential Mortgages From Securitization Corporations',
    'Other financial corporations n.e.i. 7 9 10' : 'Residential Mortgages From Other Financial Corporations',
    'Other lenders n.e.i. 8 9 10' : 'Residential Mortgages From Other Lenders',
    'Non-residential mortgages 9' : 'Non-Residential Mortgages Total',
    'Chartered banks 9 13' : 'Non-Residential Mortgages From Chartered Banks',
    'Non-banks 9 13' : 'Non-Residential Mortgages From Non-Banks',
    'Government 9 13' : 'Non-Residential Mortgages from Government Loans',
    'Non-bank financial corporations 9 13' : 'Non-Residential Mortgages from Non-Bank Financial Institutions',
    'Credit unions and caisse populaires 9 13' : 'Non-Residential Mortgages from Credit unions and caisse populaires',
    'Trust companies and mortgage loan companies 9 13' : 'Non-Residential Mortgages From Trust and Mortgage Loan Companies',
    'Financial vehicle corporations engaged in securitization 6 9 13' : 'Non-Residential Mortgages From Securitization Corporations',
    'Other financial corporations n.e.i. 7 9 13' : 'Non-Residential Mortgages From Other Financial Corporations',
    'Other lenders n.e.i. 8 9 13' : 'Non-Residential Mortgages From Other Lenders',
    'Total credit liabilities of households' : 'Total Canada Credit Liability',
})

#Clean The Third
Income_Per_Capita_indexed_by_date = ui4.set_index('year')

#Clean The Fourth
Canada_CPI_Indexed_By_Date = ui5.set_index('Year')

#Clean The Fifth
ui6 = ui6.groupby(['Province' , 'City', 'Type', 'Garage', 'Bedrooms', 'Bathrooms','Year_Built'])
Real_Estate_PriceData_Groupedby_ProvinceCityHousetypeHouselayoutYearBuilt = ui6.mean()

#Clean The Sixth
ui7 = ui7.rename(columns={'Unnamed: 0': 'Fiscal/School Year'})
ui7= ui7.transpose()
ui7.columns = ui7.iloc[0]
ui7 = ui7.iloc[1:]
ui7['Start Date'] = '08-01-' + ui7.index.str[:4]
ui7['End Date'] = '07-31-' + ui7.index.str[-4:]

#Clean The Seventh
# Clean the annual data csvs and prepare to concatenate

ui8a['Year'] = '2015'
ui8a.set_index('Year')
ui8a = ui8a.rename(columns={
    'Economy (GDP per Capita)': 'Economy',
    'Health (Life Expectancy)' : 'Life Expectancy',
    'Trust (Government Corruption)' : 'Government Trust'

})

GlobalHappiness2015 = ui8a.drop(columns=['Standard Error'])
GlobalHappiness2015 = GlobalHappiness2015.set_index('Year')


ui8b['Year'] = '2016'
ui8b= ui8b.rename(columns={
    'Economy (GDP per Capita)': 'Economy',
    'Health (Life Expectancy)' : 'Life Expectancy',
     'Trust (Government Corruption)' : 'Government Trust',
    'Happiness.Rank' : 'Happiness Rank',
    'Happiness.Score' : 'Happiness Score',})
GlobalHappiness2016 = ui8b.drop(columns=['Lower Confidence Interval', 'Upper Confidence Interval'])
GlobalHappiness2016 = GlobalHappiness2016.set_index('Year')
    




ui8c['Year'] = '2017'
ui8c= ui8c.rename(columns={
    'Economy..GDP.per.Capita.': 'Economy',
    'Health..Life.Expectancy.' : 'Life Expectancy',
    'Trust..Government.Corruption.' : 'Government Trust',
    'Dystopia.Residual' : 'Dystopia Residual',
    'Happiness.Rank' : 'Happiness Rank',
    'Happiness.Score' : 'Happiness Score'})

GlobalHappiness2017 = ui8c.drop(columns=['Whisker.high', 'Whisker.low'])
GlobalHappiness2017 = GlobalHappiness2017.set_index('Year')


ui8d['Year'] = '2018'
ui8d= ui8d.rename(columns={
    'Overall rank': 'Happiness Rank',
    'Score': 'Happiness Score',
    'GDP per capita' : 'Economy',
    'Dystopia.Residual' : 'Dystopia Residual',
    'Healthy life expectancy' : 'Life Expectancy',
    'Freedom to make life choices' : 'Freedom',
    'Perceptions of corruption' : 'Government Trust',
    'Country or region' : 'Country'
})
GlobalHappiness2018 = ui8d.set_index('Year')




ui8e['Year'] = '2019'
ui8e= ui8e.rename(columns={
    'Overall rank': 'Happiness Rank',
    'Score': 'Happiness Score',
    'GDP per capita' : 'Economy',
    'Dystopia.Residual' : 'Dystopia Residual',
    'Healthy life expectancy' : 'Life Expectancy',
    'Freedom to make life choices' : 'Freedom',
    'Perceptions of corruption' : 'Government Trust',
    'Country or region' : 'Country'
})
GlobalHappiness2019 = ui8e.set_index('Year')


ui8f['Year'] = '2020'
ui8f = ui8f.drop(columns=['Social support','upperwhisker', 'lowerwhisker'])
ui8f= ui8f.rename(columns={
    'Explained by: Social support': 'Social support',
    'Ladder score': 'Happiness Score',
    'Explained by: Log GDP per capita' : 'Economy',
    'Dystopia.Residual' : 'Dystopia Residual',
    'Explained by: Healthy life expectancy' : 'Life Expectancy',
    'Explained by: Freedom to make life choices' : 'Freedom',
    'Explained by: Perceptions of corruption' : 'Government Trust',
    'Dystopia + residual' : 'Dystopia Residual',
    'Explained by: Generosity' : 'Generosity',
    'Regional indicator' : 'Region',
    'Country name' : 'Country'
})

ui8f = ui8f.drop(columns=['Standard error of ladder score', 'Logged GDP per capita', 'Healthy life expectancy', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption', 'Ladder score in Dystopia'])
GlobalHappiness2020 = ui8f.set_index('Year')



ui8g = ui8g.drop(columns=['upperwhisker', 'Social support', 'lowerwhisker', 'Standard error of ladder score', 'Logged GDP per capita', 'Healthy life expectancy', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption', 'Ladder score in Dystopia'])
ui8g['Year'] = '2021'
ui8g= ui8g.rename(columns={
    'Explained by: Social support': 'Social support',
    'Ladder score': 'Happiness Score',
    'Explained by: Log GDP per capita' : 'Economy',
    'Dystopia.Residual' : 'Dystopia Residual',
    'Explained by: Healthy life expectancy' : 'Life Expectancy',
    'Explained by: Freedom to make life choices' : 'Freedom',
    'Explained by: Perceptions of corruption' : 'Government Trust',
    'Dystopia + residual' : 'Dystopia Residual',
    'Explained by: Generosity' : 'Generosity',
     'Regional indicator' : 'Region',
    'Country name' : 'Country'
})

GlobalHappiness2021 = ui8g.set_index('Year')

columns_to_clean = [
    'Happiness score', 
    'Whisker-high', 
    'Whisker-low', 
    'Dystopia (1.83) + residual', 
    'Explained by: GDP per capita', 
    'Explained by: Social support', 
    'Explained by: Healthy life expectancy', 
    'Explained by: Freedom to make life choices', 
    'Explained by: Generosity', 
    'Explained by: Perceptions of corruption',
]

# Clean each column and parse out the commas
for column in columns_to_clean:
    ui8h[column] = ui8h[column].str.replace(',', '.').astype(float)


ui8h['Year'] = '2022'
ui8h = ui8h.drop(columns=['Whisker-high', 'Whisker-low'])
ui8h= ui8h.rename(columns={
    'Explained by: Social support': 'Social support',
    'Happiness score': 'Happiness Score',
    'Explained by: GDP per capita' : 'Economy',
    'Dystopia (1.83) + residual' : 'Dystopia Residual',
    'Explained by: Healthy life expectancy' : 'Life Expectancy',
    'Explained by: Freedom to make life choices' : 'Freedom',
    'Explained by: Perceptions of corruption' : 'Government Trust',
    'Explained by: Generosity' : 'Generosity',
    'RANK' : 'Happiness Rank'
})
GlobalHappiness2022 = ui8h.set_index('Year')


Global_Happiness_20152022 = pd.concat([GlobalHappiness2015, GlobalHappiness2016, GlobalHappiness2017, GlobalHappiness2018, GlobalHappiness2019, GlobalHappiness2020, GlobalHappiness2021, GlobalHappiness2022])
Global_Happiness_20152022 = Global_Happiness_20152022.groupby(['Year','Region', 'Country']).mean()

#Clean The Eighth
ui9a = ui9a.drop(ui9a.index[:4])
ui9a = ui9a.transpose()
ui9a.columns = ui9a.iloc[0]
ui9a = ui9a.iloc[1:]
ui9aYears=[]
ui9aQuarters=[]
for i in ui9a.index:
    ui9aYears.append(i[-4:])
    ui9aQuarters.append(i[:2])
ui9a['Years'] = ui9aYears
ui9a['Quarters'] = ui9aQuarters
ui9a = ui9a.reset_index()
ui9a = ui9a.drop(columns=['index','Quarters'])
columns_to_convert = ui9a.columns.difference(['Years'])
ui9a[columns_to_convert] = ui9a[columns_to_convert].apply(pd.to_numeric, errors='coerce')
ui9a['Years']=pd.to_datetime(ui9a['Years'])
ui9a['Years'] = ui9a['Years'].dt.year
Total_Household_Wealth = ui9a
Total_Household_Wealth['Profile'] = 'Total All Households'

ui9b = ui9b.drop(ui9b.index[:4])
ui9b = ui9b.transpose()
ui9b.columns = ui9b.iloc[0]
ui9b = ui9b.iloc[1:]
ui9bYears=[]
ui9bQuarters=[]
for i in ui9b.index:
    ui9bYears.append(i[-4:])
    ui9bQuarters.append(i[:2])
ui9b['Years'] = ui9bYears
ui9b['Quarters'] = ui9bQuarters
ui9b = ui9b.reset_index()
ui9b = ui9b.drop(columns=['index','Quarters'])
columns_to_convert = ui9b.columns.difference(['Years'])
ui9b[columns_to_convert] = ui9b[columns_to_convert].apply(pd.to_numeric, errors='coerce')
ui9b['Years']=pd.to_datetime(ui9b['Years'])
ui9b['Years'] = ui9b['Years'].dt.year
Highest_Income_Household_Wealth = ui9b
Highest_Income_Household_Wealth['Profile'] = 'Highest Income Households'


ui9c = ui9c.drop(ui9c.index[:4])
ui9c = ui9c.transpose()
ui9c.columns = ui9c.iloc[0]
ui9c = ui9c.iloc[1:]
ui9cYears=[]
ui9cQuarters=[]
for i in ui9c.index:
    ui9cYears.append(i[-4:])
    ui9cQuarters.append(i[:2])
ui9c['Years'] = ui9cYears
ui9c['Quarters'] = ui9cQuarters
ui9c = ui9c.reset_index()
ui9c = ui9c.drop(columns=['index','Quarters'])
columns_to_convert = ui9c.columns.difference(['Years'])
ui9c[columns_to_convert] = ui9c[columns_to_convert].apply(pd.to_numeric, errors='coerce')
ui9c['Years']= pd.to_datetime(ui9c['Years'], format='%Y')
ui9c['Years'] = ui9c['Years'].dt.year
Above65_Household_Wealth = ui9c
Above65_Household_Wealth['Profile'] = 'Household Wealth Above Age 65'

ui9d = ui9d.drop(ui9d.index[:4])
ui9d = ui9d.transpose()
ui9d.columns = ui9d.iloc[0]
ui9d = ui9d.iloc[1:]
ui9dYears=[]
ui9dQuarters=[]
for i in ui9d.index:
    ui9dYears.append(i[-4:])
    ui9dQuarters.append(i[:2])
ui9d['Years'] = ui9dYears
ui9d['Quarters'] = ui9dQuarters
ui9d = ui9d.reset_index()
ui9d = ui9d.drop(columns=['index','Quarters'])
columns_to_convert = ui9d.columns.difference(['Years'])
ui9d[columns_to_convert] = ui9d[columns_to_convert].apply(pd.to_numeric, errors='coerce')
ui9d['Years']=pd.to_datetime(ui9d['Years'])
ui9d['Years'] = ui9d['Years'].dt.year
Below64_Household_Wealth = ui9d
Below64_Household_Wealth['Profile'] = 'Household Wealth Below Age 64'

ui9e = ui9e.drop(ui9e.index[:4])
ui9e = ui9e.transpose()
ui9e.columns = ui9e.iloc[0]
ui9e = ui9e.iloc[1:]
ui9eYears=[]
ui9eQuarters=[]
for i in ui9e.index:
    ui9eYears.append(i[-4:])
    ui9eQuarters.append(i[:2])
ui9e['Years'] = ui9eYears
ui9e['Quarters'] = ui9eQuarters
ui9e = ui9e.reset_index()
ui9e = ui9e.drop(columns=['index','Quarters'])
columns_to_convert = ui9e.columns.difference(['Years'])
ui9e[columns_to_convert] = ui9e[columns_to_convert].apply(pd.to_numeric, errors='coerce')
ui9e['Years']=pd.to_datetime(ui9e['Years'])
ui9e['Years'] = ui9e['Years'].dt.year
Lowest_Income_Household_Wealth = ui9e
Lowest_Income_Household_Wealth['Profile'] = 'Lowest Income Household Wealth'

ui9f = ui9f.drop(ui9f.index[:4])
ui9f = ui9f.transpose()
ui9f.columns = ui9f.iloc[0]
ui9f = ui9f.iloc[1:]
ui9fYears=[]
ui9fQuarters=[]
for i in ui9f.index:
    ui9fYears.append(i[-4:])
    ui9fQuarters.append(i[:2])
ui9f['Years'] = ui9fYears
ui9f['Quarters'] = ui9fQuarters
ui9f = ui9f.reset_index()
ui9f = ui9f.drop(columns=['index','Quarters'])
columns_to_convert = ui9f.columns.difference(['Years'])
ui9f[columns_to_convert] = ui9f[columns_to_convert].apply(pd.to_numeric, errors='coerce')
ui9f['Years']=pd.to_datetime(ui9f['Years'])
ui9f['Years'] = ui9f['Years'].dt.year
Median_Income_Household_Wealth = ui9f
Median_Income_Household_Wealth['Profile'] = 'Median Income Household Wealth'


ui9g = ui9g.drop(ui9g.index[:4])
ui9g = ui9g.transpose()
ui9g.columns = ui9g.iloc[0]
ui9g = ui9g.iloc[1:]
ui9gYears=[]
ui9gQuarters=[]
for i in ui9g.index:
    ui9gYears.append(i[-4:])
    ui9gQuarters.append(i[:2])
ui9g['Years'] = ui9gYears
ui9g['Quarters'] = ui9gQuarters
ui9g = ui9g.reset_index()
ui9g = ui9g.drop(columns=['index','Quarters'])
columns_to_convert = ui9g.columns.difference(['Years'])
ui9g[columns_to_convert] = ui9g[columns_to_convert].apply(pd.to_numeric, errors='coerce')
ui9g['Years']=pd.to_datetime(ui9g['Years'])
ui9g['Years'] = ui9g['Years'].dt.year
Under35_Household_Wealth = ui9g
Under35_Household_Wealth['Profile'] = 'Household Wealth Below Age 35'

ui9h = ui9h.drop(ui9h.index[:4])
ui9h = ui9h.transpose()
ui9h.columns = ui9h.iloc[0]
ui9h = ui9h.iloc[1:]
ui9hYears=[]
ui9hQuarters=[]
for i in ui9h.index:
    ui9hYears.append(i[-4:])
    ui9hQuarters.append(i[:2])
ui9h['Years'] = ui9hYears
ui9h['Quarters'] = ui9hQuarters
ui9h = ui9h.reset_index()
ui9h = ui9h.drop(columns=['index','Quarters'])
columns_to_convert = ui9h.columns.difference(['Years'])
ui9h[columns_to_convert] = ui9h[columns_to_convert].apply(pd.to_numeric, errors='coerce')
ui9h['Years']=pd.to_datetime(ui9h['Years'])
ui9h['Years'] = ui9h['Years'].dt.year
Under44_Household_Wealth = ui9h
Under44_Household_Wealth['Profile'] = 'Household Wealth Below Age 44'

ui9i = ui9i.drop(ui9i.index[:4])
ui9i = ui9i.transpose()
ui9i.columns = ui9i.iloc[0]
ui9i = ui9i.iloc[1:]
ui9iYears=[]
ui9iQuarters=[]
for i in ui9i.index:
    ui9iYears.append(i[-4:])
    ui9iQuarters.append(i[:2])
ui9i['Years'] = ui9iYears
ui9i['Quarters'] = ui9iQuarters
ui9i = ui9i.reset_index()
ui9i = ui9i.drop(columns=['index','Quarters'])
columns_to_convert = ui9i.columns.difference(['Years'])
ui9i[columns_to_convert] = ui9i[columns_to_convert].apply(pd.to_numeric, errors='coerce')
ui9i['Years']=pd.to_datetime(ui9i['Years'])
ui9i['Years'] = ui9i['Years'].dt.year
Under54_Household_Wealth = ui9i
Under54_Household_Wealth['Profile'] = 'Household Wealth Below Age 54'

Canada_Household_Wealth = pd.concat([Under54_Household_Wealth, Under44_Household_Wealth,Under35_Household_Wealth,Median_Income_Household_Wealth,Lowest_Income_Household_Wealth, Below64_Household_Wealth, Above65_Household_Wealth, Highest_Income_Household_Wealth, Total_Household_Wealth])
Canada_Household_Wealth = Canada_Household_Wealth.groupby(['Years', 'Profile']).mean().fillna(0)

#Clean The Tenth
ui10a['Year'] = 2001
Canada_2001_Censusus= ui10a.groupby(['Year', 'Topic', 'Characteristic', 'Prov_Name']).mean()
Canada_2001_Census = Canada_2001_Censusus.rename(columns={'Prov_Name': 'Location'})

ui10b['Year'] = 2006
Canada_2006_Censusus= ui10b.groupby(['Year', 'Topic', 'Characteristic', 'Prov_Name']).mean()
Canada_2006_Census = Canada_2006_Censusus.rename(columns={'Prov_Name': 'Location'})

ui10c['Year'] = 2011
Canada_2011_Censusus= ui10c.groupby(['Year', 'Topic', 'Characteristic', 'Prov_Name']).mean()
Canada_2011_Census = Canada_2011_Censusus.rename(columns={'Prov_Name': 'Location'})

ui10d['Year'] = 2016
ui10d = ui10d.drop(columns=['CENSUS_YEAR', 'GEO_CODE (POR)', 'GEO_LEVEL', 'GNR', 'GNR_LF', 'DATA_QUALITY_FLAG', 'ALT_GEO_CODE', 'Member ID: Profile of Canada, Provinces and Territories (2247)', 'Notes: Profile of Canada, Provinces and Territories (2247)','Dim: Sex (3): Member ID: [2]: Male', 'Dim: Sex (3): Member ID: [3]: Female'])
Canada_2016_Censusus = ui10d.rename(columns={'GEO_NAME': 'Location', 'DIM: Profile of Canada, Provinces and Territories (2247)' : 'Characteristic', 'Dim: Sex (3): Member ID: [1]: Total - Sex' : 'Total'})
Canada_2016_Censusus['Total'] = pd.to_numeric(Canada_2016_Censusus['Total'], errors='coerce')
Canada_2016_Census = Canada_2016_Censusus.groupby(['Characteristic','Year','Location']).mean()

ui10e['Year'] = 2021
Canada_2021_Censusus= ui10e.rename(columns={'GEO_NAME': 'Location', 'CHARACTERISTIC_NAME' : 'Characteristic'})
Canada_2021_Censusus['Total'] = pd.to_numeric(Canada_2021_Censusus['Total'], errors='coerce')
Canada_2021_Census = Canada_2021_Censusus.groupby(['Characteristic','Year','Location']).mean()




CensusLogic1 = pd.concat([Canada_2001_Census, Canada_2006_Census, Canada_2011_Census])
CensusLogic1 = CensusLogic1.rename_axis(index={'Prov_Name': 'Location'})
CensusLogic2 = pd.concat([Canada_2016_Census, Canada_2021_Census])

# %% [markdown]
# ## List All Variables

# %%
#2021 Income Data Grouped by Location Age Group and Income Sources
income_2021_bylocation_byage_byincomesource
# Out:
#                                                                                          1 Year Median  \
# Location              Age Group      Income Source Types
# Abbotsford - Mission  15 to 24 years After-tax income                                          18800.0
#                                      CPP/QPP - Disability benefits                                 NaN
#                                      CPP/QPP - Retirement benefits                                 NaN
#                                      CPP/QPP - Survivor benefits                                3060.0
#                                      Canada Pension Plan (CPP) and Quebec Pension Pl...         3060.0
# ...                                                                                                ...
# Yukon                 Total - Age    Provincial and territorial income taxes                    2760.0
# ...

# %%
#Household Liability and Debt Data Indexed By Date
household_liability_indexed_by_date
# Out:
# 0              Total Non-Mortgage Non-Mortgage Chartered Banks  \
# Period
# January 1990               121607                        77976
# February 1990              121405                        77820
# March 1990                 122357                        78385
# April 1990                 122780                        78566
# May 1990                   123345                        78941
# ...                           ...                          ...
# May 2023                   734976                       527514
# June 2023                  736427                       529422
# July 2023                  737670                       530576
# August 2023                739923                       531997
# September 2023             742282                       533439
#
# 0              Non-Mortgage Personal Loans Personal Loans for Automobiles  \
# Period
# January 1990                         31781                              0
# ...

# %%
#Income Per Capita Indexed By Date
Income_Per_Capita_indexed_by_date
# Out:
#             income
# year
# 1970   3399.299037
# 1971   3768.297935
# 1972   4251.175484
# 1973   4804.463248
# 1974   5576.514583
# 1975   5998.144346
# 1976   7062.131392
# 1977   7100.126170
# 1978   7247.967035
# 1979   7602.912681
# 1980   8355.968120
# 1981   9434.390652
# 1982   9619.438377
# 1983  10416.536590
# 1984  10790.328720
# 1985  11018.955850
# 1986  11482.891530
# 1987  12974.806620
# 1988  15080.283450
# 1989  16426.725480
# 1990  16838.673200
# 1991  17266.097690
# 1992  16412.083090
# 1993  15875.586730
# 1994  15755.820270
# 1995  16369.317250
# 1996  16699.826680
# 1997  17310.757750
# 1998  16622.671870
# 1999  17581.024140
# 2000  18987.382410
# 2001  18601.397240
# 2002  19232.175560
# 2003  22739.426280
# 2004  25719.147150
# 2005  29198.055690
# 2006  32738.262900
# 2007  36144.481220
# 2008  37446.486090
# 2009  32755.176820
# 2010  38420.522890
# 2011  42334.711210
# 2012  42665.255970
# 2013  42676.468370
# 2014  41039.893600
# 2015  35175.188980
# ...

# %%
#CPI Indexed By Date
Canada_CPI_Indexed_By_Date
# Out:
#       All-items   Food  Shelter  \
# Year
# 1981       49.5   54.3     50.0
# 1982       54.9   58.2     56.8
# 1983       58.1   60.4     60.9
# 1984       60.6   63.7     63.3
# 1985       63.0   65.5     65.6
# 1986       65.6   68.8     67.5
# 1987       68.5   71.8     70.5
# 1988       71.2   73.7     73.8
# 1989       74.8   76.5     78.1
# 1990       78.4   79.6     82.5
# 1991       82.8   83.4     86.3
# 1992       84.0   83.1     87.9
# 1993       85.6   84.5     89.1
# 1994       85.7   84.9     89.4
# 1995       87.6   86.9     90.4
# 1996       88.9   88.0     90.6
# 1997       90.4   89.4     90.8
# 1998       91.3   90.9     91.1
# 1999       92.9   92.0     92.3
# 2000       95.4   93.3     95.6
# 2001       97.8   97.4     99.1
# 2002      100.0  100.0    100.0
# 2003      102.8  101.7    103.2
# 2004      104.7  103.8    105.8
# 2005      107.0  106.4    109.2
# 2006      109.1  108.9    113.1
# 2007      111.5  111.8    116.9
# 2008      114.1  115.7    122.0
# ...

# %%
#Housing Price Data Grouped By Province, City, House Type, House Layout and Year Built
Real_Estate_PriceData_Groupedby_ProvinceCityHousetypeHouselayoutYearBuilt
# Out:
#                                                                       Price  \
# Province City      Type      Garage Bedrooms Bathrooms Year_Built
# AB       Calgary   Apartment 0      1        1         1953        382945.0
#                                              2         1974        831482.0
#                                              3         1952        801441.0
#                                     2        1         1955        560557.0
#                                                        2002        649357.0
# ...                                                                     ...
# QC       Vancouver House     1      5        2         1979        226723.0
#                                                        1980        273183.0
#                                                        1984        307781.0
#                                              3         2003        750609.0
# ...

# %%
#Global Happiness By year, country, region
Global_Happiness_20152022
# Out:
#                                                 Happiness Rank  \
# Year Region                     Country
# 2015 Australia and New Zealand  Australia                 10.0
#                                 New Zealand                9.0
#      Central and Eastern Europe Albania                   95.0
#                                 Armenia                  127.0
#                                 Azerbaijan                80.0
# ...                                                        ...
# 2021 Western Europe             Portugal                   NaN
#                                 Spain                      NaN
#                                 Sweden                     NaN
#                                 Switzerland                NaN
#                                 United Kingdom             NaN
#
#                                                 Happiness Score  Economy  \
# Year Region                     Country
# ...

# %%
#Canada Household Wealth Data By Year and Profile
Canada_Household_Wealth
# Out:
#                                       Life insurance and pensions as a share of total assets 3  \
# Years Profile
# 1997  Household Wealth Below Age 64                                                0.00
# 1998  Household Wealth Below Age 64                                                0.00
# 1999  Household Wealth Below Age 64                                                0.00
# 2000  Household Wealth Below Age 64                                                0.00
# 2001  Household Wealth Below Age 64                                                0.00
# ...                                                                                 ...
# 2023  Household Wealth Below Age 44                                               11.55
#       Household Wealth Below Age 54                                               16.50
#       Lowest Income Household Wealth                                               9.55
# ...

# %%
#Census Data Organized 2001 - 2011
CensusLogic1
# Out:
#                                                                                                          Total
# Year Topic                          Characteristic                                Location
# 2001 Aboriginal Population             Aboriginal identity population             Alberta             156220.0
#                                                                                   British Columbia    170025.0
#                                                                                   Canada              976305.0
#                                                                                   Manitoba            150040.0
#                                                                                   New Brunswick        16990.0
# ...                                                                                                        ...
# 2011 Population and dwelling counts Population density per square kilometre       Canada                   3.7
# ...

# %%
#Census Data Organized 2016 - 2021
CensusLogic2
# Out:
#                                                  Total
# Characteristic     Year Location
# $10,000 to $14,999 2016 Alberta                18335.0
#                         British Columbia       56262.5
#                         Canada                377627.5
#                         Manitoba               11655.0
#                         New Brunswick           6907.5
# ...                                                ...
# Unemployment rate  2021 Ontario                   12.2
#                         Prince Edward Island      10.3
#                         Quebec                     7.6
#                         Saskatchewan               8.4
#                         Yukon                      6.8
#
# [36442 rows x 1 columns]

# %% [markdown]
# # User Input Machine Learning Models

# %% [markdown]
# ## Declutter Data

# %%
#Declutter Variables
columns_to_convert = [
    'Total Non-Mortgage', 'Non-Mortgage Chartered Banks',
    'Non-Mortgage Personal Loans', 'Personal Loans for Automobiles',
    'Credit Card Liabilities', 'Non-Mortgage Lines of credit',
    'Non-Mortgage Lines Of Credit (Excluding Home Equity LsOc)',
    'Other personal loans', 'Unincorporated Business',
    'Non-bank Non-Mortgage loans', 'Government Non-Mortgage Loans',
    'Non-bank Financial Institutions Non-Mortgage Loans',
    'Non-Mortgage Loans From Credit unions and caisse populaires',
    'Non-Mortgage Loans From Trust and Mortgage Loan Companies',
    'Non-Mortgage Securities From Securitization Corporations',
    'Other Non-Mortgage financial corporations',
    'Other Non-Mortgage Lenders', 'Mortgage loans',
    'Residential Mortgages Total',
    'Residential Mortgages From Chartered Banks',
    'Residential Mortgages From Non-Banks',
    'Residential Mortgages from Government Loans',
    'Residential Mortgages from Non-Bank Financial Institutions',
    'Residential Mortgages from Credit unions and caisse populaires',
    'Residential Mortgages From Trust and Mortgage Loan Companies',
    'Residential Mortgages From Securitization Corporations',
    'Residential Mortgages From Other Financial Corporations',
    'Residential Mortgages From Other Lenders',
    'Non-Residential Mortgages Total',
    'Non-Residential Mortgages From Chartered Banks',
    'Non-Residential Mortgages From Non-Banks',
    'Non-Residential Mortgages from Government Loans',
    'Non-Residential Mortgages from Non-Bank Financial Institutions',
    'Non-Residential Mortgages from Credit unions and caisse populaires',
    'Non-Residential Mortgages From Trust and Mortgage Loan Companies',
    'Non-Residential Mortgages From Securitization Corporations',
    'Non-Residential Mortgages From Other Financial Corporations',
    'Non-Residential Mortgages From Other Lenders',
    'Total Canada Credit Liability'
]

income_profiler = ['AgeGroup_25 to 34 years',
       'AgeGroup_25 to 54 years', 'AgeGroup_25 to 64 years',
       'AgeGroup_35 to 44 years', 'AgeGroup_45 to 54 years',
       'AgeGroup_55 to 64 years', 'AgeGroup_65 years and over',
       'AgeGroup_Total - Age', '1 Year Average', 'Income Source Tpes_CPP/QPP - Disability benefits',
       'Income Source Tpes_CPP/QPP - Retirement benefits',
       'Income Source Tpes_CPP/QPP - Survivor benefits',
       'Income Source Tpes_Canada Pension Plan (CPP) and Quebec Pension Plan (QPP) benefits',
       'Income Source Tpes_Canada workers benefit (CWB)',
       'Income Source Tpes_Child benefits',
       'Income Source Tpes_EI - Other benefits',
       'Income Source Tpes_EI - Regular benefits',
       'Income Source Tpes_Employment Insurance (EI) benefits',
       'Income Source Tpes_Employment income',
       'Income Source Tpes_Federal child benefits',
       'Income Source Tpes_Goods and Services Tax (GST) credit and Harmonized Sales Tax (HST) credit',
       'Income Source Tpes_Government transfers',
       'Income Source Tpes_Government transfers not included elsewhere',
       'Income Source Tpes_Guaranteed Income Supplement (GIS) and spousal allowance',
       'Income Source Tpes_Income taxes',
       'Income Source Tpes_Investment income',
       'Income Source Tpes_Market income',
       'Income Source Tpes_Market income not included elsewhere',
       'Income Source Tpes_Net federal income tax',
       'Income Source Tpes_Net self-employment income',
       'Income Source Tpes_Old Age Security pension (OAS)',
       'Income Source Tpes_Old Age Security pension (OAS) and Guaranteed Income Supplement (GIS)',
       'Income Source Tpes_Other government transfers',
       'Income Source Tpes_Private retirement income',
       'Income Source Tpes_Provincial and territorial child benefits',
       'Income Source Tpes_Provincial and territorial income taxes',
       'Income Source Tpes_Social assistance benefits',
       'Income Source Tpes_Total income',
       'Income Source Tpes_Wages, salaries and commissions',
       "Income Source Tpes_Workers' compensation benefits"]


Income_Profile_Variables = ['Years',
 'Life insurance and pensions as a share of total assets 3',
 'Other financial assets as a share of total assets 4',
 'Non-financial assets as a share of total assets',
 'Real estate as a share of total assets',
 'Other non-financial assets as a share of total assets 5',
 'Liabilities as a share of total assets',
 'Mortgage liabilities as a share of total assets',
 'Other liabilities as a share of total assets 6',
 'Liabilities as a share of net worth',
 'Assets as a share of net worth',
 'Financial assets as a share of net worth',
 'Financial assets to non-financial assets ratio',
 "Owner's equity as a share of real estate 7",
 'Real estate as a share of disposable income 8',
 'Net worth as a share of disposable income 8',
 'Debt to disposable income ratio 8',
 'Financial assets as a share of total assets',
 'Agriculture 8',
 'Forestry, fishing, mining, quarrying, oil and gas 9 10',
 'Utilities',
 'Construction',
 'Manufacturing',
 'Services-producing sector 11',
 'Wholesale and retail trade',
 'Transportation and warehousing',
 'Finance, insurance, real estate, rental and leasing',
 'Professional, scientific and technical services',
 'Business, building and other support services 12',
 'Educational services',
 'Health care and social assistance',
 'Information, culture and recreation',
 'Accommodation and food services',
 'Other services (except public administration)',
 'Public administration',
 'Life insurance and pensions as a share of total assets 1',
 'Other financial assets as a share of total assets 2',
 'Other non-financial assets as a share of total assets 3',
 'Other liabilities as a share of total assets 4',
 "Owner's equity as a share of real estate 5",
 'Real estate as a share of disposable income 6',
 'Net worth as a share of disposable income 6',
 'Debt to disposable income ratio 6']

# %% [markdown]
# ## Income Profiling ML Model

# %%
#Income Profiling

variable3 = Canada_Household_Wealth.groupby(['Profile', 'Years']).mean()
rows_to_exclude2 = [('Household Wealth Below Age 64', year) for year in range(1997, 2024)]
Canada_Household_Wealth_By_Income = variable3[~variable3.index.isin(rows_to_exclude2)]
Canada_Household_Wealth_By_Income.reset_index(inplace=True)

incomeX = Canada_Household_Wealth_By_Income.drop(columns=['Profile'])
incomey = Canada_Household_Wealth_By_Income['Profile'].astype(str) 
incomeX_train, incomeX_test, incomey_train, incomey_test = train_test_split(incomeX, incomey, test_size=0.2, random_state=42)
initiator = RandomForestClassifier()
initiator.fit(incomeX_train, incomey_train)
income_y_pred = initiator.predict(incomeX_test)
# Evaluate the model
incomeaccuracy = accuracy_score(incomey_test, income_y_pred)
incomereport = classification_report(incomey_test, income_y_pred)


print(f'Income Machine Accuracy: {incomeaccuracy}')
print(f'Income Machine Classification Report:\n{incomereport}')
# Out:
# Income Machine Accuracy: 1.0
# Income Machine Classification Report:
#                                 precision    recall  f1-score   support
#
#      Highest Income Households       1.00      1.00      1.00         5
#  Household Wealth Above Age 65       1.00      1.00      1.00         2
#  Household Wealth Below Age 35       1.00      1.00      1.00         3
#  Household Wealth Below Age 44       1.00      1.00      1.00         5
#  Household Wealth Below Age 54       1.00      1.00      1.00         3
# Lowest Income Household Wealth       1.00      1.00      1.00         2
# Median Income Household Wealth       1.00      1.00      1.00         2
#           Total All Households       1.00      1.00      1.00         1
#
#                       accuracy                           1.00        23
#                      macro avg       1.00      1.00      1.00        23
#                   weighted avg       1.00      1.00      1.00        23

# %% [markdown]
# ## Age Profiling ML Model

# %%
#Age Profiling
AgeClassificationLogic = ui11.fillna(0)
AgeClassificationLogic = AgeClassificationLogic.transpose()
AgeClassificationLogic.reset_index(inplace=True)
AgeClassificationLogic.columns = AgeClassificationLogic.iloc[0]
AgeClassificationLogic = pd.get_dummies(AgeClassificationLogic)
AgeClassificationLogic = AgeClassificationLogic[1:]
targetcolumns = [col for col in AgeClassificationLogic.columns if col.startswith('Column Name')]
ageX = AgeClassificationLogic[targetcolumns]
agey = AgeClassificationLogic.drop(columns= targetcolumns)
agey = agey.apply(pd.to_numeric, errors='coerce')
agey = agey.dropna()
ageX_train, ageX_test, agey_train, agey_test = train_test_split(ageX, agey, test_size=0.2, random_state=15)
agitator = StandardScaler()
ageX_train_scaled = agitator.fit_transform(ageX_train)
ageX_test_scaled = agitator.transform(ageX_test)
ageknn = KNeighborsRegressor(n_neighbors=3)
ageknn.fit(ageX_train_scaled, agey_train)

#Model Evaluation
agey_pred = ageknn.predict(ageX_test_scaled)
agemae = mean_absolute_error(agey_test, agey_pred)
print(f'Profile Machine Mean Absolute Error: {agemae}')
ager2 = r2_score(agey_test, agey_pred)
print(f'Profile Machine R-squared: {ager2}')

#Age Profile Comparison
ui1

#Age Profile Comparison
variable1 = Canada_Household_Wealth.groupby(['Profile']).mean()
rows_to_exclude = ['Highest Income Households', 'Lowest Income Household Wealth', 'Median Income Household Wealth']
Canada_Household_Wealth_By_Age = variable1[~variable1.index.isin(rows_to_exclude)]
Canada_Household_Wealth_By_Age.reset_index(inplace=True)

#Historical Data
CensusLogic1ByAge = CensusLogic1.xs('Age Characteristics of the Population', level='Topic')
CensusLogic1ByAge.reset_index(inplace=True)
# Out:
# Profile Machine Mean Absolute Error: 0.06607604282022887
# Profile Machine R-squared: 0.5586501884907997

# %% [markdown]
# ## User Data Analysis

# %% [markdown]
# ### Pull Lex Answers As Variables

# %%
user_age = df['Age'].astype(int)
user_assets = df['Assets']
user_charity = df['Charitable']
user_clothing = df['Clothing']
user_country = df['Country']
user_creditcard = df['CreditCard']
user_creditscore = df['CreditScore']
user_debtservice = df['DebtService']
user_education = df['Education']
user_food = df['EssentialFood']
user_householdcount = df['HouseholdNumber']
user_housing = df['Housing']
user_income = df['Income']
user_incomesource = df['IncomeSource'].astype(str)
user_liabilities = df['Liablilities']
user_location = df['Location'].astype(str)
user_medical = df['Medical']
user_name = df['Name']
user_luxuryfood = df['Non-essentialFood']
user_job = df['Occupation']
user_personals = df['PersonalLoan']
user_state = df['State']
user_transportation = df['Transportation']
user_vacation = df['VacationTravel']
user_wellness = df['Wellness']

# %% [markdown]
# ### Filter Down To User Segments

# %%
# Assuming user_age, user_country, and user_income_source are variables with appropriate values

# Filter based on user_age
if user_age[0] > 64: 
    user_ui1 = ui1[ui1['Age Group']== "65 years and over"]
elif 55<= user_age[0] <= 64: 
    user_ui1 = ui1[ui1['Age Group']== '55 to 64 years']
elif 45<= user_age[0] <= 54: 
    user_ui1 = ui1[ui1['Age Group']== '45 to 54 years'] 
elif 35<= user_age[0] <= 44: 
    user_ui1 = ui1[ui1['Age Group']== '35 to 44 years'] 
elif 25<= user_age[0] <= 34: 
    user_ui1 = ui1[ui1['Age Group']== '25 to 34 years'] 
elif 15<= user_age[0] <= 24: 
    user_ui1 = ui1[ui1['Age Group']== '25 to 34 years']    
    
# Filter based on user_country
if user_country[0] == 'Canada':
    user_ui2 = user_ui1[user_ui1['Location'] == "Canada"]
else:
    user_ui2 = user_ui1  # No additional filtering if user_country is not 'Canada'

# %%
# Filter based on user_income_source
#if user_ui2['Income Source Types'] == 'Employment income':
    #user_ui3 = user_ui2[user_ui2['Income Source Types'] == 'Employment income']
#else:
    #print('Did not work')

# %%
#if user_age > 65: 
    #user_chw = Canada_Household_Wealth_By_Age[Canada_Household_Wealth_By_Age['Profile']== "Household Wealth Above Age 65"]
#elif 35 >= user_age: 
    #user_chw = Canada_Household_Wealth_By_Age[Canada_Household_Wealth_By_Age['Profile']== "Household Wealth Below Age 35"]      
#elif 36 <= user_age <= 43: 
    #user_chw = Canada_Household_Wealth_By_Age[Canada_Household_Wealth_By_Age['Profile']== "Household Wealth Below Age 44"]  
#elif 45 <= user_age <= 53: 
    #user_chw = Canada_Household_Wealth_By_Age[Canada_Household_Wealth_By_Age['Profile']== "Household Wealth Below Age 54"]  
#elif 54 <= user_age <= 65: 
    #user_chw = Canada_Household_Wealth_By_Age[Canada_Household_Wealth_By_Age['Profile']== "Household Wealth Below Age 64"]

# %% [markdown]
# ### Cross-Analyze User Data

# %%
#Historical Data
CensusLocation2 = CensusLogic2.groupby(['Year', 'Location']).mean()
CensusLocation1 = CensusLogic1.groupby(['Year', 'Location']).mean()

#Location Population Comparison
CensusLocationmerge = pd.concat([CensusLocation1, CensusLocation2]).groupby(['Location']).mean()

#Historical Data
GlobalHappinessByCountry = Global_Happiness_20152022.groupby(['Country', 'Year']).mean()
Canada_Happiness_20152022 = Global_Happiness_20152022.xs('Canada', level='Country')

#Average House Prices Per City
RealEstatePriceDataByCity = Real_Estate_PriceData_Groupedby_ProvinceCityHousetypeHouselayoutYearBuilt.groupby(['City']).mean()

#Average House Prices Per house Type
RealEstatePriceDataByType = Real_Estate_PriceData_Groupedby_ProvinceCityHousetypeHouselayoutYearBuilt.groupby(['Type', 'City']).mean()

#Income Comparison Data
Canada2021_income_by_location= income_2021_bylocation_byage_byincomesource.groupby(['Location']).mean()
Canada2021_income_by_locationntype = income_2021_bylocation_byage_byincomesource.groupby(['Income Source Types','Location']).mean()

#Combined Data For Neural Network Analysis
LocationLogic = pd.concat([CensusLocationmerge, GlobalHappinessByCountry, RealEstatePriceDataByCity, Canada2021_income_by_location])

# %%
#Food
CA1

#660 Credit Score
CA4

#Rent
CA7

#Income Type Second Reference
CA10
# Out:
#        REF_DATE      GEO           DGUID                  Statistics  \
# 0          1999   Canada  2016A000011124                       Value
# 1          1999   Canada  2016A000011124                       Value
# 2          1999   Canada  2016A000011124                       Value
# 3          1999   Canada  2016A000011124                       Value
# 4          1999   Canada  2016A000011124                       Value
# ...         ...      ...             ...                         ...
# 90427      2022  Nunavut     2016A000262  Value per consumption unit
# 90428      2022  Nunavut     2016A000262  Value per consumption unit
# 90429      2022  Nunavut     2016A000262  Value per consumption unit
# 90430      2022  Nunavut     2016A000262  Value per consumption unit
# 90431      2022  Nunavut     2016A000262  Value per consumption unit
#
#       Characteristics          Income, consumption and savings      UOM  \
# ...

# %%
#Date
#Canada_RealEstate_PricesbyDate = Real_Estate_PriceData_Groupedby_ProvinceCityHousetypeHouselayoutYearBuilt.groupby('Year_Built').mean()
#household_liability_indexed_by_date.index = pd.to_datetime(household_liability_indexed_by_date.index).year
#household_liability_indexed_by_date = household_liability_indexed_by_date.groupby(['Period']).mean()
#Income_Per_Capita_indexed_by_date
#Canada_CPI_Indexed_By_Date
#Canada_Happiness_20152022 = Global_Happiness_20152022.xs('Canada', level='Country')
#Canada_Happiness_ByYear = Canada_Happiness_20152022.groupby('Year').mean()
#Global_Happiness_ByYear = Global_Happiness_20152022.groupby('Year').mean()
#variable2 = Canada_Household_Wealth.xs('Total All Households', level='Profile')
#CanadaHouseholdWealthAnnualAverages = variable2.groupby('Years').mean()
#CensusDate1 = CensusLogic1.groupby(['Year']).mean()
#CensusDateLogic2 = CensusLogic2.groupby(['Year']).mean()
#DateLogic = pd.concat([CensusDateLogic2, CensusDate1, CanadaHouseholdWealthAnnualAverages, Canada_Happiness_ByYear, Global_Happiness_ByYear, Canada_CPI_Indexed_By_Date, Income_Per_Capita_indexed_by_date, household_liability_indexed_by_date, Canada_RealEstate_PricesbyDate])

#DateX = DateLogic.index.fillna('')
#Datey = DateLogic[columns_to_convert].fillna('')

# Split the data into training and testing sets
#DateX_train, DateX_test, Datey_train, Datey_test = train_test_split(DateX, Datey, test_size=0.2, random_state=15)

# Standardize the input data
#Datonator = StandardScaler()
#DateX_train_scaled = Datonator.fit_transform(DateX_train.values.reshape(-1, 1))
#DateX_test_scaled = Datonator.transform(DateX_test.values.reshape(-1, 1))

# Build and train the KNeighborsRegressor model
#Dateknn = KNeighborsRegressor(n_neighbors=5)
#Dateknn.fit(DateX_train_scaled, Datey_train)


#Model Evaluation
#Datey_pred = Dateknn.predict(DateX_test_scaled)
#Datey_test = pd.to_numeric(Datey_test, errors='coerce')
#datemae = mean_absolute_error(Datey_test, Datey_pred)
#print(f'Date Machine Mean Absolute Error: {datemae}')
#dater2 = r2_score(Datey_test, agey_pred)
#print(f'Date Machine R-squared: {dater2}')

# %%
#user_age_classifier = pd.DataFrame(columns=ageX.columns)
#user_age_classifier.loc[0] = [False] * len(user_age_classifier.columns)

#def classify_age(x):
    #user_age_classifier[f'Column Name_{x}'] = True

        
#classify_age(user_age)
#age_predict = ageknn.predict(user_age_classifier)
